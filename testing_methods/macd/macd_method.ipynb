# %% [markdown]
# ## Imports

# %%
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import yfinance as yf
import functions as func

# %% [markdown]
# ## Fetching data
#
# ### name = name of the stock or cryptocurrency we want to fetch
# ### start = date to start fetching from
# ### end = date to finish fetching to

# %%
name = "NKLA"
start = "2020-01-01"
#end = "2020-05-08" #date of buy
end = "2020-06-27" #date of sell

# %%
data = func.get_data(name, start, end)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2019-12-31  10.317000  10.320000  10.315000  10.320000  10.320000      6500
# 2020-01-02  10.310000  10.320000  10.310000  10.320000  10.320000     60300
# 2020-01-03  10.300000  10.300000  10.300000  10.300000  10.300000     15000
# 2020-01-06  10.325000  10.350000  10.320000  10.320000  10.320000     68700
# 2020-01-07  10.440000  10.440000  10.330000  10.330000  10.330000     42900
# ...               ...        ...        ...        ...        ...       ...
# 2020-06-22  64.010002  70.000000  63.900002  70.000000  70.000000  17769200
# 2020-06-23  69.260002  75.709999  68.300003  75.059998  75.059998  20805200
# 2020-06-24  74.260002  76.300003  69.010002  74.190002  74.190002  19044900
# 2020-06-25  72.019997  74.720001  70.199997  71.099998  71.099998  13303700
# 2020-06-26  72.089996  73.649002  62.869999  63.549999  63.549999  15326600
#
# [124 rows x 6 columns]

# %% [markdown]
# # Create Wallet

# %%
#func.create_wallet(name, 10000, "MACD")

# %% [markdown]
# ## Plotting the data

# %%
func.plot_data(data)

# %% [markdown]
# # Moving Average Convergence Divergence

# %%
data['12_period_ema'] = (data['High'].ewm(span=12, adjust=False).mean() + data['Low'].ewm(span=12, adjust=False).mean() + data['Close'].ewm(span=12, adjust=False).mean())/3
data['26_period_ema'] = (data['High'].ewm(span=26, adjust=False).mean() + data['Low'].ewm(span=26, adjust=False).mean() + data['Close'].ewm(span=26, adjust=False).mean())/3

# %%
print(data['12_period_ema'])
# Out:
# Date
# 2019-12-31    10.318333
# 2020-01-02    10.318077
# 2020-01-03    10.315296
# 2020-01-06    10.317558
# 2020-01-07    10.325113
#                 ...
# 2020-06-22    60.585952
# 2020-06-23    62.499395
# 2020-06-24    64.140514
# 2020-06-25    65.350691
# 2020-06-26    65.556688
# Name: 12_period_ema, Length: 124, dtype: float64

# %%
print(data['26_period_ema'])
# Out:
# Date
# 2019-12-31    10.318333
# 2020-01-02    10.318210
# 2020-01-03    10.316861
# 2020-01-06    10.317834
# 2020-01-07    10.321451
#                 ...
# 2020-06-22    48.805229
# 2020-06-23    50.599163
# 2020-06-24    52.270830
# 2020-06-25    53.732744
# 2020-06-26    54.692516
# Name: 26_period_ema, Length: 124, dtype: float64

# %%
data['macd'] = data['12_period_ema'] - data['26_period_ema']

# %%
print(data['macd'])
# Out:
# Date
# 2019-12-31     0.000000
# 2020-01-02    -0.000133
# 2020-01-03    -0.001565
# 2020-01-06    -0.000276
# 2020-01-07     0.003662
#                 ...
# 2020-06-22    11.780723
# 2020-06-23    11.900233
# 2020-06-24    11.869685
# 2020-06-25    11.617948
# 2020-06-26    10.864172
# Name: macd, Length: 124, dtype: float64

# %%
data['signal_line'] = data['macd'].ewm(span=9, adjust=False).mean()

# %%
print(data['signal_line'])
# Out:
# Date
# 2019-12-31     0.000000
# 2020-01-02    -0.000027
# 2020-01-03    -0.000334
# 2020-01-06    -0.000323
# 2020-01-07     0.000474
#                 ...
# 2020-06-22    11.172548
# 2020-06-23    11.318085
# 2020-06-24    11.428405
# 2020-06-25    11.466313
# 2020-06-26    11.345885
# Name: signal_line, Length: 124, dtype: float64

# %%
func.plot_macd(data)

# %% [markdown]
# ## When MACD line crosses signal line and is going to be above signal line we buy,
# ## When MACD line crosses signal line and is going to be under signal line we sell

# %%
func.macd_buy_sell(name, end, data)
# Out:
# SEEEELLL!!!!
# Sold at the price of: 63.54999923706055 $
