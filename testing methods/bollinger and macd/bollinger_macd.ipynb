# %% [markdown]
# ## Imports

# %%
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import yfinance as yf
import functions as func

# %% [markdown]
# ## Fetching data
#
# ### name = name of the stock or cryptocurrency we want to fetch
# ### start = date to start fetching from
# ### end = date to finish fetching to

# %%
name = "NKLA"
start = "2020-03-25"
#end = "2020-06-04" #buying date
#end = "2020-09-05" #selling date

# %%
data = func.get_data(name, start, end)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2020-03-24  11.060000  11.180000  10.750000  10.810000  10.810000    853600
# 2020-03-25  10.910000  11.310000  10.700000  10.950000  10.950000    535100
# 2020-03-26  10.900000  11.230000  10.900000  11.050000  11.050000    383500
# 2020-03-27  11.000000  11.040000  10.820000  10.880000  10.880000    273800
# 2020-03-30  10.960000  11.130000  10.900000  10.975000  10.975000    228200
# ...               ...        ...        ...        ...        ...       ...
# 2020-08-31  41.099998  43.279999  40.299999  40.810001  40.810001  11367200
# 2020-09-01  40.320000  41.465000  39.119999  41.000000  41.000000   8133800
# 2020-09-02  40.540001  41.570000  38.209999  39.419998  39.419998   8694900
# 2020-09-03  39.000000  39.330002  35.549999  36.130001  36.130001  10455300
# 2020-09-04  36.720001  37.360001  32.799999  35.549999  35.549999   8560900
#
# [116 rows x 6 columns]

# %% [markdown]
# # Create Wallet

# %%
#func.create_wallet(name, 10000, "BB & MACD")

# %% [markdown]
# ## Plotting the data

# %%
func.plot_data(data)

# %% [markdown]
# # Bollinger bands

# %%
data['MA_20'] = (data['High'].rolling(window=20).mean() + data['Low'].rolling(window=20).mean() + data['Close'].rolling(window=20).mean())/3
data['STD_20'] = (data['High'].rolling(window=20).std() + data['Low'].rolling(window=20).std() + data['Close'].rolling(window=20).std())/3

# %%
print(data['MA_20'])
# Out:
# Date
# 2020-03-24          NaN
# 2020-03-25          NaN
# 2020-03-26          NaN
# 2020-03-27          NaN
# 2020-03-30          NaN
#                 ...
# 2020-08-31    40.648817
# 2020-09-01    40.771067
# 2020-09-02    41.034067
# 2020-09-03    41.062567
# 2020-09-04    40.991567
# Name: MA_20, Length: 116, dtype: float64

# %%
print(data['STD_20'])
# Out:
# Date
# 2020-03-24         NaN
# 2020-03-25         NaN
# 2020-03-26         NaN
# 2020-03-27         NaN
# 2020-03-30         NaN
#                 ...
# 2020-08-31    3.087263
# 2020-09-01    3.025223
# 2020-09-02    2.648191
# 2020-09-03    2.603324
# 2020-09-04    2.752407
# Name: STD_20, Length: 116, dtype: float64

# %%
data['upper_band'] = data['MA_20'] + (data['STD_20']*2)
data['lower_band'] = data['MA_20'] - (data['STD_20']*2)

# %%
print(data['upper_band'])
# Out:
# Date
# 2020-03-24          NaN
# 2020-03-25          NaN
# 2020-03-26          NaN
# 2020-03-27          NaN
# 2020-03-30          NaN
#                 ...
# 2020-08-31    46.823343
# 2020-09-01    46.821513
# 2020-09-02    46.330448
# 2020-09-03    46.269215
# 2020-09-04    46.496380
# Name: upper_band, Length: 116, dtype: float64

# %%
print(data['lower_band'])
# Out:
# Date
# 2020-03-24          NaN
# 2020-03-25          NaN
# 2020-03-26          NaN
# 2020-03-27          NaN
# 2020-03-30          NaN
#                 ...
# 2020-08-31    34.474290
# 2020-09-01    34.720620
# 2020-09-02    35.737685
# 2020-09-03    35.855918
# 2020-09-04    35.486753
# Name: lower_band, Length: 116, dtype: float64

# %%
func.plot_bollinger(data)

# %% [markdown]
# # Moving Average Convergence Divergence

# %%
data['12_period_ema'] = (data['High'].ewm(span=12, adjust=False).mean() + data['Low'].ewm(span=12, adjust=False).mean() + data['Close'].ewm(span=12, adjust=False).mean())/3
data['26_period_ema'] = (data['High'].ewm(span=26, adjust=False).mean() + data['Low'].ewm(span=26, adjust=False).mean() + data['Close'].ewm(span=26, adjust=False).mean())/3

# %%
print(data['12_period_ema'])
# Out:
# Date
# 2020-03-24    10.913334
# 2020-03-25    10.924616
# 2020-03-26    10.945444
# 2020-03-27    10.940504
# 2020-03-30    10.949913
#                 ...
# 2020-08-31    40.406247
# 2020-09-01    40.425030
# 2020-09-02    40.318615
# 2020-09-03    39.808572
# 2020-09-04    39.105202
# Name: 12_period_ema, Length: 116, dtype: float64

# %%
print(data['26_period_ema'])
# Out:
# Date
# 2020-03-24    10.913334
# 2020-03-25    10.918766
# 2020-03-26    10.929227
# 2020-03-27    10.928050
# 2020-03-30    10.933503
#                 ...
# 2020-08-31    41.096566
# 2020-09-01    41.054475
# 2020-09-02    40.956612
# 2020-09-03    40.663777
# 2020-09-04    40.261769
# Name: 26_period_ema, Length: 116, dtype: float64

# %%
data['macd'] = data['12_period_ema'] - data['26_period_ema']

# %%
print(data['macd'])
# Out:
# Date
# 2020-03-24    0.000000
# 2020-03-25    0.005850
# 2020-03-26    0.016216
# 2020-03-27    0.012454
# 2020-03-30    0.016410
#                 ...
# 2020-08-31   -0.690319
# 2020-09-01   -0.629445
# 2020-09-02   -0.637998
# 2020-09-03   -0.855205
# 2020-09-04   -1.156567
# Name: macd, Length: 116, dtype: float64

# %%
data['signal_line'] = data['macd'].ewm(span=9, adjust=False).mean()

# %%
print(data['signal_line'])
# Out:
# Date
# 2020-03-24    0.000000
# 2020-03-25    0.001170
# 2020-03-26    0.004179
# 2020-03-27    0.005834
# 2020-03-30    0.007949
#                 ...
# 2020-08-31   -0.968923
# 2020-09-01   -0.901027
# 2020-09-02   -0.848421
# 2020-09-03   -0.849778
# 2020-09-04   -0.911136
# Name: signal_line, Length: 116, dtype: float64

# %%
func.plot_macd(data)

# %% [markdown]
# # Plotting Bollinger Bands and MACD

# %%
func.plot_bollinger_macd(data)

# %% [markdown]
# ### When bollinger bands squeeze and macd line is above signal line we go buy
# ### If bollinger bands spread and macd line gets under signal line we sell

# %%
func.bollinger_macd_buy_sell(name, data, end)
# Out:
# U dont own any coins/stocks atm to sell!
