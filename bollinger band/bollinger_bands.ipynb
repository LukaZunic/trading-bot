# %% [markdown]
# ## Imports

# %%
import plotly.graph_objs as go
import numpy as np
import pandas as pd
import yfinance as yf
import functions as func

# %% [markdown]
# ## Fetching data
#
# ### name = name of the stock or cryptocurrency we want to fetch
# ### start = date to start fetching from
# ### end = date to finish fetching to

# %%
name = "NKLA"
start = "2020-01-01"
end = "2021-04-22"

# %%
data = func.get_data(name, start, end)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
#               Open   High     Low  Close  Adj Close    Volume
# Date
# 2019-12-31  10.317  10.32  10.315  10.32      10.32      6500
# 2020-01-02  10.310  10.32  10.310  10.32      10.32     60300
# 2020-01-03  10.300  10.30  10.300  10.30      10.30     15000
# 2020-01-06  10.325  10.35  10.320  10.32      10.32     68700
# 2020-01-07  10.440  10.44  10.330  10.33      10.33     42900
# ...            ...    ...     ...    ...        ...       ...
# 2021-04-15  11.880  11.91  10.610  10.63      10.63  23472400
# 2021-04-16  10.610  11.05  10.370  10.98      10.98  13241400
# 2021-04-19  10.900  10.93  10.195  10.29      10.29  13412500
# 2021-04-20  10.040  10.35   9.570   9.65       9.65  17294700
# 2021-04-21   9.650  10.54   9.370  10.29      10.29  15497300
#
# [329 rows x 6 columns]

# %% [markdown]
# ## Plotting the data

# %%
func.plot_data(data)

# %% [markdown]
# # Bollinger bands

# %%
data['MA_20'] = (data['High'].rolling(window=20).mean() + data['Low'].rolling(window=20).mean() + data['Close'].rolling(window=20).mean())/3
data['STD_20'] = (data['High'].rolling(window=20).std() + data['Low'].rolling(window=20).std() + data['Close'].rolling(window=20).std())/3

# %%
print(data['MA_20'])
# Out:
# Date
# 2019-12-31          NaN
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-06          NaN
# 2020-01-07          NaN
#                 ...
# 2021-04-15    13.559550
# 2021-04-16    13.343717
# 2021-04-19    13.106967
# 2021-04-20    12.809633
# 2021-04-21    12.552300
# Name: MA_20, Length: 329, dtype: float64

# %%
print(data['STD_20'])
# Out:
# Date
# 2019-12-31         NaN
# 2020-01-02         NaN
# 2020-01-03         NaN
# 2020-01-06         NaN
# 2020-01-07         NaN
#                 ...
# 2021-04-15    1.295296
# 2021-04-16    1.379465
# 2021-04-19    1.446695
# 2021-04-20    1.473975
# 2021-04-21    1.482648
# Name: STD_20, Length: 329, dtype: float64

# %%
data['upper_band'] = data['MA_20'] + (data['STD_20']*2)
data['lower_band'] = data['MA_20'] - (data['STD_20']*2)

# %%
print(data['upper_band'])
# Out:
# Date
# 2019-12-31          NaN
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-06          NaN
# 2020-01-07          NaN
#                 ...
# 2021-04-15    16.150142
# 2021-04-16    16.102647
# 2021-04-19    16.000358
# 2021-04-20    15.757583
# 2021-04-21    15.517596
# Name: upper_band, Length: 329, dtype: float64

# %%
print(data['lower_band'])
# Out:
# Date
# 2019-12-31          NaN
# 2020-01-02          NaN
# 2020-01-03          NaN
# 2020-01-06          NaN
# 2020-01-07          NaN
#                 ...
# 2021-04-15    10.968958
# 2021-04-16    10.584786
# 2021-04-19    10.213576
# 2021-04-20     9.861683
# 2021-04-21     9.587004
# Name: lower_band, Length: 329, dtype: float64

# %%
func.plot_bollinger(data)
